# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanov85/Homework1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
user_table = pd.read_csv("/content/user_table.csv")
user_table
# Out:
#        user_id        date   device     sex
# 0       450007  2015-02-28  Desktop  Female
# 1       756838  2015-01-13  Desktop    Male
# 2       568983  2015-04-09  Desktop    Male
# 3       190794  2015-02-18  Desktop  Female
# 4       537909  2015-01-15  Desktop    Male
# ...        ...         ...      ...     ...
# 90395   307667  2015-03-30  Desktop  Female
# 90396   642989  2015-02-08  Desktop  Female
# 90397   659645  2015-04-13  Desktop    Male
# 90398   359779  2015-03-23  Desktop    Male
# 90399   438929  2015-03-26   Mobile  Female
#
# [90400 rows x 4 columns]

# %%
user_table.shape
# Out:
# (90400, 4)

# %%
home_page = pd.read_csv("/content/home_page_table.csv")
home_page.head()
# Out:
#    user_id       page
# 0   313593  home_page
# 1   468315  home_page
# 2   264005  home_page
# 3   290784  home_page
# 4   639104  home_page

# %%
home_page.shape
# Out:
# (90400, 2)

# %%
sum(home_page.duplicated())
# Out:
# 0

# %%
search_page = pd.read_csv("/content/search_page_table.csv")
search_page.head()
# Out:
#    user_id         page
# 0    15866  search_page
# 1   347058  search_page
# 2   577020  search_page
# 3   780347  search_page
# 4   383739  search_page

# %%
search_page.shape
# Out:
# (45200, 2)

# %%
payment_page = pd.read_csv("/content/payment_page_table.csv")
payment_page.head()
# Out:
#    user_id          page
# 0   253019  payment_page
# 1   310478  payment_page
# 2   304081  payment_page
# 3   901286  payment_page
# 4   195052  payment_page

# %%
payment_page.shape
# Out:
# (6030, 2)

# %%
payment_confirmation = pd.read_csv("/content/payment_confirmation_table.csv")
payment_confirmation.head()
# Out:
#    user_id                       page
# 0   123100  payment_confirmation_page
# 1   704999  payment_confirmation_page
# 2   407188  payment_confirmation_page
# 3   538348  payment_confirmation_page
# 4   841681  payment_confirmation_page

# %%
payment_confirmation.shape
# Out:
# (452, 2)

# %%
home_page = home_page.rename(columns = {"page": "home_page"})
search_page = search_page.rename(columns = {"page": "search_page"})
payment_page = payment_page.rename(columns = {"page": "payment_page"})
payment_confirmation = payment_confirmation.rename(columns = {"page": "payment_confirmation"})

# %%
df = user_table.merge(home_page, on = "user_id", how = "left").merge(search_page, on = "user_id", how = "left")\
        .merge(payment_page, on = "user_id", how = "left").merge(payment_confirmation, on = "user_id", how = "left")
df.head()
# Out:
#    user_id        date   device     sex  home_page  search_page payment_page  \
# 0   450007  2015-02-28  Desktop  Female  home_page          NaN          NaN
# 1   756838  2015-01-13  Desktop    Male  home_page          NaN          NaN
# 2   568983  2015-04-09  Desktop    Male  home_page  search_page          NaN
# 3   190794  2015-02-18  Desktop  Female  home_page  search_page          NaN
# 4   537909  2015-01-15  Desktop    Male  home_page          NaN          NaN
#
#   payment_confirmation
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
df.shape
# Out:
# (90400, 8)

# %%
df["home_page"] = df["home_page"].apply(lambda x: 1 if x == "home_page" else 0)
df["search_page"] = df["search_page"].apply(lambda x: 1 if x == "search_page" else 0)
df["payment_page"] = df["payment_page"].apply(lambda x: 1 if x == "payment_page" else 0)
df["payment_confirmation"] = df["payment_confirmation"].apply(lambda x: 1 if x == "payment_confirmation_page" else 0)

df.head()
# Out:
#    user_id        date   device     sex  home_page  search_page  payment_page  \
# 0   450007  2015-02-28  Desktop  Female          1            0             0
# 1   756838  2015-01-13  Desktop    Male          1            0             0
# 2   568983  2015-04-09  Desktop    Male          1            1             0
# 3   190794  2015-02-18  Desktop  Female          1            1             0
# 4   537909  2015-01-15  Desktop    Male          1            0             0
#
#    payment_confirmation
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
df["device"].value_counts()
# Out:
# Desktop    60200
# Mobile     30200
# Name: device, dtype: int64

# %%
df["payment_confirmation"].agg({"users": "count", "payers": sum})
# Out:
# users     90400
# payers      452
# Name: payment_confirmation, dtype: int64

# %%
summary = df[["home_page", "search_page", "payment_page", "payment_confirmation"]].sum().reset_index()
summary.head()
# Out:
#                   index      0
# 0             home_page  90400
# 1           search_page  45200
# 2          payment_page   6030
# 3  payment_confirmation    452

# %%
summary = summary.rename(columns = {"index" : "stage", 0: "number"})
summary.head()
# Out:
#                   stage  number
# 0             home_page   90400
# 1           search_page   45200
# 2          payment_page    6030
# 3  payment_confirmation     452

# %%
from plotly import graph_objects as go

fig = go.Figure(go.Funnel(
    y = summary["stage"],
    x = summary["number"],
    textinfo = "value + percent previous"
))

fig.update_layout(
    title = "Воронка конверсии Интернет-магазина",
    title_x = 0.5,
    autosize = False,
    width = 1200,
    height = 600

)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c17a343f-0e61-4de2-a760-62e428431941" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c17a343f-0e61-4de2-a760-62e428431941")) {                    Plotly.newPlot(                        "c17a343f-0e61-4de2-a760-62e428431941",                        [{"textinfo":"value+percent previous","x":[90400,45200,6030,452],"y":["home_page","search_page","payment_page","payment_confirmation"],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl", ...

# %%
dfg = df.groupby("device")[["home_page", "search_page", "payment_page", "payment_confirmation"]].sum().unstack("device").unstack("device").reset_index()

dfg.columns.name = None
dfg = dfg.rename(columns = {"index": "Page"})
dfg.head()
# Out:
#                    Page  Desktop  Mobile
# 0             home_page    60200   30200
# 1           search_page    30100   15100
# 2          payment_page     3010    3020
# 3  payment_confirmation      150     302

# %%
fig = go.Figure(go.Funnel(
    y = dfg ["Page"],
    x = dfg ["Desktop"],
    textinfo = "value + percent previous",
    name = "Desktop",
    constraintext = "outside",
    textposition = "inside"
))

fig.add_trace(go.Funnel(
    y = dfg ["Page"],
    x = dfg ["Mobile"],
    textinfo = "value + percent previous",
    name = "Mobile",
    constraintext = "outside",
    textposition = "inside"
))

fig.update_layout(
    title = "Воронка конверсии по типам устройств",
    title_x = 0.5,
    autosize = False,
    width = 1200,
    height = 600

)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="aef6fc4a-1203-47fd-a6af-1372098bd8d2" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aef6fc4a-1203-47fd-a6af-1372098bd8d2")) {                    Plotly.newPlot(                        "aef6fc4a-1203-47fd-a6af-1372098bd8d2",                        [{"constraintext":"outside","name":"Desktop","textinfo":"value+percent previous","textposition":"inside","x":[60200,30100,3010,150],"y":["home_page","search_page","payment_page","payment_confirmation"],"type":"funnel"},{"constraintext":"outside","name":"Mobile","textinfo":"value+percent previous","textposition":"inside","x":[30200,15100,3020,302],"y":["home_page","search_page","payment_page","payment_confirmation"],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo", ...

# %%
pd.pivot_table(df, index = "sex", columns = "device", values = "home_page", aggfunc = "sum", margins = True)
# Out:
# device  Desktop  Mobile    All
# sex
# Female    29997   15078  45075
# Male      30203   15122  45325
# All       60200   30200  90400

# %%
pd.crosstab(index = df["sex"], columns = df["device"], margins = True, normalize = True)
# Out:
# device   Desktop    Mobile       All
# sex
# Female  0.331825  0.166792  0.498617
# Male    0.334104  0.167279  0.501383
# All     0.665929  0.334071  1.000000

# %%
df.groupby(["sex", "device"])["user_id"].count().reset_index()
# Out:
#       sex   device  user_id
# 0  Female  Desktop    29997
# 1  Female   Mobile    15078
# 2    Male  Desktop    30203
# 3    Male   Mobile    15122

# %%
df.groupby(["sex", "device"])["user_id"].count().unstack("device")
# Out:
# device  Desktop  Mobile
# sex
# Female    29997   15078
# Male      30203   15122

# %%
from pandas.core.groupby import groupby
(df.groupby("sex")["search_page"].sum() - df.groupby("sex")["payment_page"].sum())/df.groupby("sex")["search_page"].sum()
# Out:
# sex
# Female    0.863292
# Male      0.869917
# dtype: float64

# %%
pd.crosstab(index= df["sex"], columns= df["payment_confirmation"], normalize= True)
# Out:
# payment_confirmation         0         1
# sex
# Female                0.495951  0.002666
# Male                  0.499049  0.002334

# %%
df.pivot_table(index = ["sex"], values = "payment_confirmation")
# Out:
#         payment_confirmation
# sex
# Female              0.005347
# Male                0.004655
