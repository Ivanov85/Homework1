# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivanov85/Homework1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libs
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
r = requests.get("https://archive.ics.uci.edu/ml/datasets/wine+quality")

print(r.status_code)
# Out:
# 200

# %%
white_wine_df = pd.read_csv('winequality-white.csv', sep=";")
red_wine_df = pd.read_csv('winequality-red.csv', sep=";")

# %%
ww = white_wine_df.loc[:]
ww["color"] = "white"
rw = red_wine_df.loc[:]
rw["color"] = "red"
wine_df = pd.concat([ww, rw], ignore_index=True)

# %%
white_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
red_wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
assert white_wine_df.columns.all() == red_wine_df.columns.all()
",".join(list(white_wine_df.columns))
# Out:
# 'fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality'

# %%
assert white_wine_df.notnull().all().all()
white_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
assert red_wine_df.notnull().all().all()
red_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine_df = white_wine_df.astype("category")
red_wine_df = red_wine_df.astype("category")
wine_df = wine_df.astype("category")

# %%
white_wine_df.mean()
# Out:
# <ipython-input-169-4d5aa2f6bdb3>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   white_wine_df.mean()
# Series([], dtype: float64)

# %%
red_wine_df.mean()
# Out:
# <ipython-input-170-97a36b920f06>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   red_wine_df.mean()
# Series([], dtype: float64)

# %%
mean_diff = white_wine_df.mean() - red_wine_df.mean()
mean_diff_abs = mean_diff.apply(lambda x: abs(x))
mean_diff[mean_diff_abs >= 1.0]

# %%
sns.countplot(data=white_wine_df, x="quality")
plt.title("White Wines")
# Out:
# Text(0.5, 1.0, 'White Wines')

# %%
white_wine_df.quality.describe()
# Out:
# count     4898
# unique       7
# top          6
# freq      2198
# Name: quality, dtype: int64

# %%
x = sns.countplot(data=red_wine_df, x="quality")
plt.title("Red Wines")
# Out:
# Text(0.5, 1.0, 'Red Wines')

# %%
red_wine_df.quality.describe()
# Out:
# count     1599
# unique       6
# top          5
# freq       681
# Name: quality, dtype: int64

# %%
x = white_wine_df.groupby(["quality"]).mean()
lower_quals = x.loc[:4].mean()
higher_quals = x.loc[7:].mean()
ww_perc_means = (higher_quals - lower_quals) / white_wine_df.mean() * 100
ww_perc_means
# Out:
# <ipython-input-175-27c4edd826fd>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   x = white_wine_df.groupby(["quality"]).mean()
# <ipython-input-175-27c4edd826fd>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ww_perc_means = (higher_quals - lower_quals) / white_wine_df.mean() * 100
# Series([], dtype: float64)

# %%
ww_perc_means[abs(ww_perc_means) > 5]
# Out:
# Series([], dtype: float64)

# %%
ww_perc_means[abs(ww_perc_means) > 10]
# Out:
# Series([], dtype: float64)

# %%
x = red_wine_df.groupby(["quality"]).mean()
lower_quals = x.loc[:4].mean()
higher_quals = x.loc[7:].mean()
rw_perc_means = (higher_quals - lower_quals) / red_wine_df.mean() * 100
rw_perc_means
# Out:
# <ipython-input-178-34570e1c139f>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   x = red_wine_df.groupby(["quality"]).mean()
# <ipython-input-178-34570e1c139f>:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rw_perc_means = (higher_quals - lower_quals) / red_wine_df.mean() * 100
# Series([], dtype: float64)

# %%
rw_perc_means[abs(rw_perc_means) > 5]
# Out:
# Series([], dtype: float64)

# %%
rw_perc_means[abs(rw_perc_means) > 10]
# Out:
# Series([], dtype: float64)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
fig.set_size_inches(14.5, 4.5)
fig.dpi = 300
sns.stripplot(data=white_wine_df, x="quality", y="total sulfur dioxide", jitter=True, ax=ax1)
sns.stripplot(data=white_wine_df, x="quality", y="free sulfur dioxide", jitter=True, ax=ax2)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
fig.set_size_inches(14.5, 4.5)
fig.dpi = 300
sns.stripplot(data=red_wine_df, x="quality", y="total sulfur dioxide", jitter=True, ax=ax1)
sns.stripplot(data=red_wine_df, x="quality", y="free sulfur dioxide", jitter=True, ax=ax2)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
sns.stripplot(data=wine_df, x="quality", y="sulphates", jitter=True, hue="color")
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
white_wine_df.groupby("quality")["alcohol"].describe()
# Out:
#           count  unique   top   freq
# quality
# 3          20.0    15.0  11.0    4.0
# 4         163.0    44.0   9.0   11.0
# 5        1457.0    62.0   9.4  131.0
# 6        2198.0    78.0   9.5   90.0
# 7         880.0    68.0  11.0   43.0
# 8         175.0    34.0   8.8   11.0
# 9           5.0     5.0  10.4    1.0

# %%
red_wine_df.groupby("quality")["alcohol"].describe()
# Out:
#          count  unique   top  freq
# quality
# 3         10.0    10.0   8.4   1.0
# 4         53.0    25.0   9.6   6.0
# 5        681.0    42.0   9.5  97.0
# 6        638.0    56.0   9.5  40.0
# 7        199.0    42.0  11.0  11.0
# 8         18.0    15.0  11.0   2.0

# %%
sns.stripplot(data=wine_df, x="quality", y="alcohol", hue="color")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
heat_table = wine_df[["quality", "alcohol"]].copy()
heat_table["alcohol"] = heat_table.alcohol.apply(func=lambda x: round(x * 2) / 2)
heat_table = heat_table.groupby(["quality", "alcohol"])["alcohol"].count().reset_index(name='counts')
sns.heatmap(heat_table.pivot("quality", "alcohol", "counts"))
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
sns.stripplot(data=wine_df, hue="color", x="quality", y="chlorides")
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
white_wine_df[["volatile acidity", "citric acid", "quality"]].groupby("quality").describe(percentiles=[])
# Out:
#         volatile acidity                     citric acid
#                    count unique   top   freq       count unique   top   freq
# quality
# 3                   20.0   15.0  0.26    3.0        20.0   17.0  0.38    2.0
# 4                  163.0   63.0  0.28   12.0       163.0   55.0  0.49    9.0
# 5                 1457.0   89.0  0.28   91.0      1457.0   81.0  0.26   69.0
# 6                 2198.0   96.0  0.22  130.0      2198.0   79.0  0.30  150.0
# 7                  880.0   62.0  0.18   56.0       880.0   52.0  0.28   82.0
# 8                  175.0   42.0  0.28   12.0       175.0   34.0  0.36   18.0
# 9                    5.0    4.0  0.36    2.0         5.0    5.0  0.34    1.0

# %%
white_wine_df[["quality", "free sulfur dioxide", "chlorides"]].groupby("quality").describe(percentiles=[])
# Out:
#         free sulfur dioxide                    chlorides
#                       count unique   top  freq     count unique    top  freq
# quality
# 3                      20.0   17.0   5.0   4.0      20.0   15.0  0.041   3.0
# 4                     163.0   52.0   6.0   9.0     163.0   53.0  0.054   9.0
# 5                    1457.0   96.0  35.0  39.0    1457.0  120.0  0.046  75.0
# 6                    2198.0  100.0  36.0  71.0    2198.0  110.0  0.047  97.0
# 7                     880.0   78.0  29.0  55.0     880.0   56.0  0.036  50.0
# 8                     175.0   51.0  29.0  11.0     175.0   39.0  0.034  15.0
# 9                       5.0    5.0  31.0   1.0       5.0    5.0  0.032   1.0

# %%
qual8[["quality", "chlorides", "alcohol", "citric acid", "sulphates"]].describe(percentiles=[])
# Out:
#         quality  chlorides  alcohol  citric acid  sulphates
# count       175    175.000    175.0       175.00     175.00
# unique        1     39.000     34.0        34.00      49.00
# top           8      0.034      8.8         0.36       0.38
# freq        175     15.000     11.0        18.00      14.00
